# %%
# %pip install cryptography
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.9 MB 495.5 kB/s eta 0:00:06
#    -- ------------------------------------- 0.2/2.9 MB 1.5 MB/s eta 0:00:02
#    ------------ --------------------------- 0.9/2.9 MB 5.3 MB/s eta 0:00:01
#    ------------------------- -------------- 1.8/2.9 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.9 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 9.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/182.0 kB ? eta -:--:--
#    --------------------------------------- 182.0/182.0 kB 10.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/117.6 kB ? eta -:--:--
#    ---------------------------------------- 117.6/117.6 kB ? eta 0:00:00
# ...
